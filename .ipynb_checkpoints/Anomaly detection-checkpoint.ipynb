# %%
import hashlib
import json
from time import time
from sklearn.model_selection import train_test_split
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_blobs
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import make_scorer, f1_score, accuracy_score
from river import neighbors
from river import metrics
from river import cluster
from river import stream
import statistics
from river import datasets
from river import evaluate
from river import linear_model
from river import metrics
from river import optim
from river import preprocessing
from river import stream

# %%
class Blockchain(object):
    def __init__(self):
        self.chain = []
        self.pending_data = []

        self.new_block(previous_hash="Initial block doesn't have previous hash", proof=100)
        
    def new_block(self, proof, previous_hash=None):
        block = {
            'index': len(self.chain),
            'timestamp': time(),
            'data': self.pending_data,
            'proof': proof,
            'previous_hash': previous_hash or self.chain[-1]['hash'],
            
        }
        block['hash'] = self.hash(block)
        block_hash = self.hash(block)
        self.pending_data = []
        self.chain.append(block)

        return block, block_hash
        
    @property
    def last_block(self):

        return self.chain[-1]

    def new_data(self, machine_id, source, data):
        data = {

            'machine': machine_id,
            'source': source,
            'data': data

        }
        self.pending_data.append(data)
        return self.last_block['index'] + 1

    def hash(self, block):
        block_to_hash = block.copy()
        block_to_hash.pop('hash', None)
        string_object = json.dumps(block_to_hash, sort_keys=True)
        block_string = string_object.encode()

        raw_hash = hashlib.sha256(block_string)
        hex_hash = raw_hash.hexdigest()

        return hex_hash

    def verify(self, verbose=True): 
        flag = True
        for i in range(0,len(self.chain)-1):
            if self.chain[i]['index'] != i:
                flag = False
                if verbose:
                    print(f'!!!Wrong block index at block {i}!!!')
            if self.chain[i]['hash'] != self.chain[i+1]['previous_hash']:
                flag = False
                if verbose:
                    print(f'!!!Wrong previous hash at block {i+1}!!!')
            if self.chain[i]['hash'] != self.hash(self.chain[i]):
                flag = False
                if verbose:
                    print(f'!!!Wrong hash at block {i}!!!')
            # if block[i].timestamp >block[i+1].timestamp:
            #     flag = False
            # if verbose:
                # print(f'Backdating at block {i}.')
        if flag and verbose:
            print('No modification')
        return flag

# %%
def filter(model, incoming_data):
    #useful_data = { 0 : incoming_data[2]}
    useful_data = np.array(incoming_data[2]).reshape(-1, 1)
    #category = model.predict_one(useful_data)
    category = model.predict(useful_data)
    return category

def stat_validate_result(result, incoming_data, mu, sigma):
    data = incoming_data[2]
    lcl = mu - 3*sigma
    ucl = mu + 3*sigma
    # checking if number in range
    if (lcl <= data <= ucl) and result:
        print(f'{data} and {result} are equal')
        return True
    elif (lcl > data or data > ucl) and not result:
        print(f'{data} and {result} are validated')
        return True
    else:
        return False

# %%
def validate_result(incoming_data, mu, sigma):
    data = incoming_data[2]
    lcl = mu - 3*sigma
    ucl = mu + 3*sigma
    # checking if number in range
    if (lcl <= data <= ucl):
        return 0 #normal
    else:
        return 1 #outlier

# %%
#generating random sample
number_of_proper_data = 10000
number_of_anomal_data = 100
random_state = 42
rng = np.random.RandomState(random_state)

proper_data = rng.normal(loc=0.0, scale=1.0, size=[number_of_proper_data,1])
#anomalous_data = rng.normal(loc=5.0, scale=1.0, size=[number_of_anomal_data,1])

# data property
mu = proper_data.mean()
sigma = proper_data.std()

# %%
anomalous_data = rng.uniform(low=-100, high=100, size=(number_of_anomal_data, 1))

# %% [markdown]
# Plotting distribution of our data

# %%
fig, ax1 = plt.subplots(figsize=(16, 8))

color = 'tab:blue'
ax1.set_xlabel('some value')
ax1.set_ylabel('normal data', color=color)
ax1.hist(proper_data, 30)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:orange'
ax2.set_ylabel('oultiers', color=color)  # we already handled the x-label with ax1
ax2.hist(anomalous_data, 30, color=color, alpha=0.5)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped

plt.show()

# %%
#preparing data for classifier
X = np.concatenate((proper_data, anomalous_data))


# making target data (we will use only for validation, not training)
y_proper = np.full((number_of_proper_data,), 1)
y_anomalous = np.full((number_of_anomal_data,), -1)
Y = np.concatenate((y_proper, y_anomalous))

# %% [markdown]
# Our data is prepared, let's train SVM classifier to detect anomalies. Hyperparameters was chosen using intuition.

# %%
from sklearn.svm import OneClassSVM
from sklearn.metrics import accuracy_score
# OCSVM hyperparameters
nu = 0.05
gamma = 2.0

# Fit the One-Class SVM
clf = OneClassSVM(gamma=gamma, kernel="sigmoid", nu=nu)
clf.fit(X)
y_pred = clf.predict(X)
print(f'Accuracy score is:{accuracy_score(Y, y_pred)}')
# Out:
# Accuracy score is:0.9498019801980198

# %% [markdown]
# Not bad, but we need to choose hyperparameters which will suit our model better. Also, I will add another metric - F1-score.
# Here I will use new experimental method from scikit learn which can choose better hyperparameter set, based on chosen metric.

# %%
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV
from sklearn.metrics import make_scorer, f1_score
from sklearn.metrics import accuracy_score

param_grid = {  'gamma': [2, 1, 3, 0.1, 4.5, 5],
                'kernel': ["sigmoid", "rbf", "linear"],
                'nu':[0.05, 0.01, 0.02, 0.5, 0.005, 0.001, 0.0005]}

base_estimator = OneClassSVM()

sh = HalvingGridSearchCV(base_estimator, param_grid, scoring = make_scorer(f1_score)).fit(X, Y)
sh.best_estimator_
# Out:
# OneClassSVM(gamma=5, kernel='sigmoid', nu=0.001)

# %% [markdown]
# Now we have best estimator for our case. We can directly put it inside our classificator.

# %%
# Fit the One-Class SVM
clf = sh.best_estimator_
clf.fit(X)
y_pred = clf.predict(X)
print(f'Accuracy score is:{accuracy_score(Y, y_pred)}')
print(f'F1 score is:{f1_score(Y, y_pred)}')
# Out:
# Accuracy score is:0.99
# F1 score is:0.9949728734259121

# %% [markdown]
# Result is even better!

# %% [markdown]
# Extra: while reading about one-class SVM I have noticed information about Local Outlier Factor (LOF). Which is more suitable for intrsion detection (Reference:https://en.wikipedia.org/wiki/Local_outlier_factor). Here my implementation.

# %%
from sklearn.neighbors import LocalOutlierFactor

clf = LocalOutlierFactor()
y_pred=clf.fit_predict(X)
print(f'Accuracy score is:{accuracy_score(Y, y_pred)}')
print(f'F1 score is:{f1_score(Y, y_pred)}')
# Out:
# Accuracy score is:0.9905940594059406
# F1 score is:0.9952658593711068

# %% [markdown]
# I want to say, that LOF is really better than one-class SVM and it doesn't need any setup.

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDOneClassSVM.html

# %%
from sklearn import linear_model
clf1 = linear_model.SGDOneClassSVM(random_state=42)
y_pred=clf1.fit_predict(X)
print(f'Accuracy score is:{accuracy_score(Y, y_pred)}')
print(f'F1 score is:{f1_score(Y, y_pred)}')
# Out:
# Accuracy score is:0.6248514851485149
# F1 score is:0.7677312572794703

# %%
epochs = 500
learning_history = np.zeros(epochs)
for i in range(epochs):
    new_data = np.random.normal(loc=0.0, scale=1.0, size=[number_of_proper_data,1])
    clf1.partial_fit(new_data)
    y_pred = clf1.predict(X)
    learning_history[i]=f1_score(Y, y_pred)
plt.plot(learning_history);

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, stratify=Y, test_size=0.7, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=2)
neigh.fit(X_train, y_train)
y_pred=neigh.predict(X_test)
print(f'Accuracy score is:{accuracy_score(y_test, y_pred)}')
print(f'F1 score is:{f1_score(y_test, y_pred)}')
# Out:
# Accuracy score is:0.9994342291371995
# F1 score is:0.9997143673236218

# %% [markdown]
# k-NN shows more better picture, but need labels for data

# %%
from sklearn.neighbors import (NeighborhoodComponentsAnalysis,
KNeighborsClassifier)
from sklearn.pipeline import Pipeline

nca = NeighborhoodComponentsAnalysis(random_state=42)
knn = KNeighborsClassifier(n_neighbors=3)
nca_pipe = Pipeline([('nca', nca), ('knn', knn)])
nca_pipe.fit(X_train, y_train)

print(nca_pipe.score(X_test, y_test))
# Out:
# 0.9991513437057992

# %%
from sklearn.cluster import KMeans
import numpy as np

kmeans = KMeans(n_clusters=3, random_state=0).fit(X)
y_pred = kmeans.predict(X)
y_pred[y_pred > 0] = -1
y_pred[y_pred == 0] = 1
print(f'Accuracy score is:{accuracy_score(Y, y_pred)}')
print(f'F1 score is:{f1_score(Y, y_pred)}')
# Out:
# C:\Users\boskolk\Anaconda3\envs\research\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Accuracy score is:0.9975247524752475
# F1 score is:0.9987515605493134

# %%
#preparing data for classifier
X_train = np.concatenate((proper_data, anomalous_data))

# making target data

y_proper = np.full((number_of_proper_data,), True)
y_anomalous = np.full((number_of_anomal_data,), False)
y_train = np.concatenate((y_proper, y_anomalous))

# %%
from sklearn.neural_network import MLPClassifier

MLP = MLPClassifier(random_state=42, max_iter=300, activation='logistic').fit(X_train, y_train)

# %%
print(f'score: {MLP.score(X_train, y_train)}')
# Out:
# score: 0.9995049504950495

# %%
#initializing blockchains
accel = Blockchain()
temp = Blockchain()

# %%
val_passed_counter = 0
val_failed_counter = 0
n_incoming = 1000

for i in range(n_incoming):

    incoming_data = ["a_01", "accel", rng.normal(loc=0.0, scale=20.0)]
    X_data_point = np.array(incoming_data[2]).reshape(-1, 1)
    result = filter(MLP,incoming_data)
    
    if stat_validate_result(result, incoming_data, mu, sigma):
        val_passed_counter +=1
        y_data_point = np.array(result).reshape(1,)
        #model.learn_one({ 0 : incoming_data[2]}, result)
        MLP.partial_fit(X_data_point, y_data_point)
        if not result:
            print(f"Skipping {i}-th data point...")
        else:
            accel.new_data(incoming_data[0],incoming_data[1],incoming_data[2])
            accel.new_block(42)
            if accel.verify(verbose=False):
                print(f'Accelerometer info from {incoming_data[0]} has been added successfully!')
    else:
        val_failed_counter +=1
        y_data_point = np.array(not result).reshape(1,)
        #model.learn_one({ 0 : incoming_data[2]}, not result)
        MLP.partial_fit(X_data_point, y_data_point)
        print(f"Skipping {i}-th data point...")
# Out:
# -19.369672939237912 and [False] are validated
# Skipping 0-th data point...
# -27.63538377135408 and [False] are validated
# Skipping 1-th data point...
# 15.401002178351717 and [False] are validated
# Skipping 2-th data point...
# 30.122944815498933 and [False] are validated
# Skipping 3-th data point...
# -8.77699980956343 and [False] are validated
# Skipping 4-th data point...
# -22.78123015232702 and [False] are validated
# Skipping 5-th data point...
# -49.16338861098037 and [False] are validated
# Skipping 6-th data point...
# -19.615296873250752 and [False] are validated
# Skipping 7-th data point...
# -2.273136849980804 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 31.982464816734684 and [False] are validated
# Skipping 9-th data point...
# 13.46267384465937 and [False] are validated
# Skipping 10-th data point...
# 6.10170809413506 and [False] are validated
# Skipping 11-th data point...
# -8.002393226022619 and [False] are validated
# Skipping 12-th data point...
# -11.663314345119126 and [False] are validated
# Skipping 13-th data point...
# 28.11295195015927 and [False] are validated
# Skipping 14-th data point...
# Skipping 15-th data point...
# -42.05201383842044 and [False] are validated
# Skipping 16-th data point...
# -13.470792957944857 and [False] are validated
# Skipping 17-th data point...
# -17.164320635432535 and [False] are validated
# Skipping 18-th data point...
# -10.925280183549297 and [False] are validated
# Skipping 19-th data point...
# 11.258213205701704 and [False] are validated
# Skipping 20-th data point...
# -2.148897635884988 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -1.5373081400732405 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 26.269463226504733 and [False] are validated
# Skipping 23-th data point...
# -13.929221795733769 and [False] are validated
# Skipping 24-th data point...
# 37.28399051774699 and [False] are validated
# Skipping 25-th data point...
# -13.426151827421721 and [False] are validated
# Skipping 26-th data point...
# 1.7839639322514276 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -5.624071908055338 and [False] are validated
# Skipping 28-th data point...
# 2.468382670019221 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 8.891839901462578 and [False] are validated
# Skipping 30-th data point...
# 8.67670480177753 and [False] are validated
# Skipping 31-th data point...
# -15.062346612411599 and [False] are validated
# Skipping 32-th data point...
# -22.458293548951413 and [False] are validated
# Skipping 33-th data point...
# 50.063435818114215 and [False] are validated
# Skipping 34-th data point...
# -9.679686792011061 and [False] are validated
# Skipping 35-th data point...
# 13.984248773439731 and [False] are validated
# Skipping 36-th data point...
# -32.152826210463935 and [False] are validated
# Skipping 37-th data point...
# -5.5922543980935355 and [False] are validated
# Skipping 38-th data point...
# -2.5439876796488585 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 9.45630139855665 and [False] are validated
# Skipping 40-th data point...
# -54.44908281983878 and [False] are validated
# Skipping 41-th data point...
# Skipping 42-th data point...
# -22.99482910735786 and [False] are validated
# Skipping 43-th data point...
# 6.486914223898477 and [False] are validated
# Skipping 44-th data point...
# -20.72658393676326 and [False] are validated
# Skipping 45-th data point...
# -17.109653918511626 and [False] are validated
# Skipping 46-th data point...
# -5.4725522078653634 and [False] are validated
# Skipping 47-th data point...
# -21.046589392063908 and [False] are validated
# Skipping 48-th data point...
# -9.510688934707098 and [False] are validated
# Skipping 49-th data point...
# -23.867515370866307 and [False] are validated
# Skipping 50-th data point...
# -36.66340903397455 and [False] are validated
# Skipping 51-th data point...
# 20.35914104858719 and [False] are validated
# Skipping 52-th data point...
# -25.920973856478568 and [False] are validated
# Skipping 53-th data point...
# -3.5736177521596706 and [False] are validated
# Skipping 54-th data point...
# 15.057821629875699 and [False] are validated
# Skipping 55-th data point...
# -12.298882050320863 and [False] are validated
# Skipping 56-th data point...
# -16.50331799491076 and [False] are validated
# Skipping 57-th data point...
# 4.5247617733484295 and [False] are validated
# Skipping 58-th data point...
# 22.35867645454304 and [False] are validated
# Skipping 59-th data point...
# -23.38630530172938 and [False] are validated
# Skipping 60-th data point...
# Skipping 61-th data point...
# -34.64989189934655 and [False] are validated
# Skipping 62-th data point...
# -7.8640200736438 and [False] are validated
# Skipping 63-th data point...
# 0.6840936907615089 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -17.092492835101314 and [False] are validated
# Skipping 65-th data point...
# -9.139836676504629 and [False] are validated
# Skipping 66-th data point...
# -28.164535366149003 and [False] are validated
# Skipping 67-th data point...
# 1.5415722276298724 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 21.113884977662995 and [False] are validated
# Skipping 69-th data point...
# -21.942877395409273 and [False] are validated
# Skipping 70-th data point...
# -12.453435331047658 and [False] are validated
# Skipping 71-th data point...
# 10.050924929083635 and [False] are validated
# Skipping 72-th data point...
# 24.241814386454724 and [False] are validated
# Skipping 73-th data point...
# -29.863796244178626 and [False] are validated
# Skipping 74-th data point...
# -3.3756947483189865 and [False] are validated
# Skipping 75-th data point...
# 5.6626164463905 and [False] are validated
# Skipping 76-th data point...
# -2.0411278125769594 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -49.53584133754174 and [False] are validated
# Skipping 78-th data point...
# 10.021800186175438 and [False] are validated
# Skipping 79-th data point...
# 30.38672702181288 and [False] are validated
# Skipping 80-th data point...
# 2.3332350233900687 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -20.622121065885267 and [False] are validated
# Skipping 82-th data point...
# -10.262544927285662 and [False] are validated
# Skipping 83-th data point...
# 35.39826135311186 and [False] are validated
# Skipping 84-th data point...
# 18.199250817211173 and [False] are validated
# Skipping 85-th data point...
# 12.800532367686586 and [False] are validated
# Skipping 86-th data point...
# 7.128251670687521 and [False] are validated
# Skipping 87-th data point...
# -13.222742243819447 and [False] are validated
# Skipping 88-th data point...
# -4.0114236131153715 and [False] are validated
# Skipping 89-th data point...
# -1.5584547135703173 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 10.991486321288878 and [False] are validated
# Skipping 91-th data point...
# 30.17837788533807 and [False] are validated
# Skipping 92-th data point...
# 22.366762735862558 and [False] are validated
# Skipping 93-th data point...
# -28.387687115920812 and [False] are validated
# Skipping 94-th data point...
# 4.479899378020974 and [False] are validated
# Skipping 95-th data point...
# 14.735266903357939 and [False] are validated
# Skipping 96-th data point...
# 12.377206602892707 and [False] are validated
# Skipping 97-th data point...
# -12.584675267748388 and [False] are validated
# Skipping 98-th data point...
# 58.28218431536723 and [False] are validated
# Skipping 99-th data point...
# -25.541691246622378 and [False] are validated
# Skipping 100-th data point...
# -21.663768933321 and [False] are validated
# Skipping 101-th data point...
# 4.671901625231526 and [False] are validated
# Skipping 102-th data point...
# 42.33606109927707 and [False] are validated
# Skipping 103-th data point...
# -16.723897014083416 and [False] are validated
# Skipping 104-th data point...
# -5.316567312939846 and [False] are validated
# Skipping 105-th data point...
# 21.545873460313857 and [False] are validated
# Skipping 106-th data point...
# -0.35724309775467 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -6.692077090605913 and [False] are validated
# Skipping 108-th data point...
# 11.312658037734401 and [False] are validated
# Skipping 109-th data point...
# 5.450359804591862 and [False] are validated
# Skipping 110-th data point...
# 20.608775712735827 and [False] are validated
# Skipping 111-th data point...
# 25.82937778130727 and [False] are validated
# Skipping 112-th data point...
# 6.140061200107234 and [False] are validated
# Skipping 113-th data point...
# 5.834654507566181 and [False] are validated
# Skipping 114-th data point...
# 4.28221964572267 and [False] are validated
# Skipping 115-th data point...
# 9.782611132985753 and [False] are validated
# Skipping 116-th data point...
# 1.1034127574292785 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -0.012169646445789009 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 23.932542416544848 and [False] are validated
# Skipping 119-th data point...
# 30.322323607100863 and [False] are validated
# Skipping 120-th data point...
# -30.151058892668416 and [False] are validated
# Skipping 121-th data point...
# 0.20042303481138143 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -13.773888668904695 and [False] are validated
# Skipping 123-th data point...
# -6.2194293297214465 and [False] are validated
# Skipping 124-th data point...
# 8.050324194706429 and [False] are validated
# Skipping 125-th data point...
# 13.388767430849368 and [False] are validated
# Skipping 126-th data point...
# -2.242528872226898 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -38.26680669445606 and [False] are validated
# Skipping 128-th data point...
# -19.300911611523592 and [False] are validated
# Skipping 129-th data point...
# 17.92999340400332 and [False] are validated
# Skipping 130-th data point...
# -54.80852844069862 and [False] are validated
# Skipping 131-th data point...
# 23.748543033639997 and [False] are validated
# Skipping 132-th data point...
# 10.424599812890827 and [False] are validated
# Skipping 133-th data point...
# 26.323521630600442 and [False] are validated
# Skipping 134-th data point...
# -3.971383737619209 and [False] are validated
# Skipping 135-th data point...
# -41.2281084804581 and [False] are validated
# Skipping 136-th data point...
# 8.60725283012996 and [False] are validated
# Skipping 137-th data point...
# 25.493062480766824 and [False] are validated
# Skipping 138-th data point...
# 18.49443611026842 and [False] are validated
# Skipping 139-th data point...
# -13.253829669760709 and [False] are validated
# Skipping 140-th data point...
# 1.7352215092529342 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -10.65672537559848 and [False] are validated
# Skipping 142-th data point...
# -16.385329283787442 and [False] are validated
# Skipping 143-th data point...
# 19.10777142359702 and [False] are validated
# Skipping 144-th data point...
# -23.95064622530324 and [False] are validated
# Skipping 145-th data point...
# -17.876328611632253 and [False] are validated
# Skipping 146-th data point...
# -22.08051266944771 and [False] are validated
# Skipping 147-th data point...
# -29.804950465980934 and [False] are validated
# Skipping 148-th data point...
# 2.928285836852069 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 23.230060969639517 and [False] are validated
# Skipping 150-th data point...
# -3.697535124905313 and [False] are validated
# Skipping 151-th data point...
# -30.11495601128333 and [False] are validated
# Skipping 152-th data point...
# 16.798890794840553 and [False] are validated
# Skipping 153-th data point...
# 33.71403508069943 and [False] are validated
# Skipping 154-th data point...
# -12.92484648293189 and [False] are validated
# Skipping 155-th data point...
# -9.571085334354365 and [False] are validated
# Skipping 156-th data point...
# 10.313212601667885 and [False] are validated
# Skipping 157-th data point...
# 32.43747495570103 and [False] are validated
# Skipping 158-th data point...
# -10.396682914504522 and [False] are validated
# Skipping 159-th data point...
# -26.6489956199641 and [False] are validated
# Skipping 160-th data point...
# 12.628372125448129 and [False] are validated
# Skipping 161-th data point...
# 15.981361462845987 and [False] are validated
# Skipping 162-th data point...
# 0.12262900870453705 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -11.162665193149014 and [False] are validated
# Skipping 164-th data point...
# 19.887574619840926 and [False] are validated
# Skipping 165-th data point...
# 10.560720090959286 and [False] are validated
# Skipping 166-th data point...
# -15.368710338069857 and [False] are validated
# Skipping 167-th data point...
# 0.9818946261134299 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -27.034150640492932 and [False] are validated
# Skipping 169-th data point...
# 13.717809128758402 and [False] are validated
# Skipping 170-th data point...
# -5.244671387657118 and [False] are validated
# Skipping 171-th data point...
# -8.714216647694743 and [False] are validated
# Skipping 172-th data point...
# -0.6574897030486831 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 0.8061539866049565 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 17.89860123131121 and [False] are validated
# Skipping 175-th data point...
# 11.82181062650443 and [False] are validated
# Skipping 176-th data point...
# -3.1281855758560537 and [False] are validated
# Skipping 177-th data point...
# 15.273362994379905 and [False] are validated
# Skipping 178-th data point...
# 8.01474507383226 and [False] are validated
# Skipping 179-th data point...
# -8.531992725720741 and [False] are validated
# Skipping 180-th data point...
# -2.4943631647297178 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# Skipping 182-th data point...
# 10.105226863484035 and [False] are validated
# Skipping 183-th data point...
# -7.340452294432835 and [False] are validated
# Skipping 184-th data point...
# -7.808183728432666 and [False] are validated
# Skipping 185-th data point...
# 39.375146188679174 and [False] are validated
# Skipping 186-th data point...
# 18.794709634942084 and [False] are validated
# Skipping 187-th data point...
# -15.212013288502781 and [False] are validated
# Skipping 188-th data point...
# 11.418819878843966 and [False] are validated
# Skipping 189-th data point...
# 2.3670013131035446 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 7.831023505201876 and [False] are validated
# Skipping 191-th data point...
# 2.746826491302091 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 23.792852909704717 and [False] are validated
# Skipping 193-th data point...
# 6.912406893028917 and [False] are validated
# Skipping 194-th data point...
# -1.2417739642857482 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 20.843811539660347 and [False] are validated
# Skipping 196-th data point...
# 4.66570082175744 and [False] are validated
# Skipping 197-th data point...
# 2.4295715865811567 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 6.280452049722291 and [False] are validated
# Skipping 199-th data point...
# -1.8721804673273301 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 0.18453985990937805 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -11.733891775237455 and [False] are validated
# Skipping 202-th data point...
# -15.023344392477576 and [False] are validated
# Skipping 203-th data point...
# -19.971407729648792 and [False] are validated
# Skipping 204-th data point...
# -27.839665735941523 and [False] are validated
# Skipping 205-th data point...
# -17.59434722769113 and [False] are validated
# Skipping 206-th data point...
# Skipping 207-th data point...
# 2.06235164891274 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -5.42593126295281 and [False] are validated
# Skipping 209-th data point...
# -47.11406980254716 and [False] are validated
# Skipping 210-th data point...
# 31.491727155246846 and [False] are validated
# Skipping 211-th data point...
# 21.729602457807637 and [False] are validated
# Skipping 212-th data point...
# 8.915197024342573 and [False] are validated
# Skipping 213-th data point...
# 38.14981345106536 and [False] are validated
# Skipping 214-th data point...
# -19.547282349674212 and [False] are validated
# Skipping 215-th data point...
# 37.752502412520094 and [False] are validated
# Skipping 216-th data point...
# -19.304281535010958 and [False] are validated
# Skipping 217-th data point...
# 4.774758505827132 and [False] are validated
# Skipping 218-th data point...
# -25.476746502684087 and [False] are validated
# Skipping 219-th data point...
# 0.29388191088733584 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 7.723329959967774 and [False] are validated
# Skipping 221-th data point...
# Skipping 222-th data point...
# 14.277548881802751 and [False] are validated
# Skipping 223-th data point...
# 1.980288989745146 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -10.448294567550185 and [False] are validated
# Skipping 225-th data point...
# -11.336266356046785 and [False] are validated
# Skipping 226-th data point...
# 16.21827545231393 and [False] are validated
# Skipping 227-th data point...
# -13.07484059613935 and [False] are validated
# Skipping 228-th data point...
# 18.30805940969874 and [False] are validated
# Skipping 229-th data point...
# 24.45423585663862 and [False] are validated
# Skipping 230-th data point...
# -33.3742772469226 and [False] are validated
# Skipping 231-th data point...
# 22.658527746020695 and [False] are validated
# Skipping 232-th data point...
# 41.20845396889398 and [False] are validated
# Skipping 233-th data point...
# 5.040075224038569 and [False] are validated
# Skipping 234-th data point...
# 11.981683705896447 and [False] are validated
# Skipping 235-th data point...
# 20.740106487383173 and [False] are validated
# Skipping 236-th data point...
# -5.509646303580445 and [False] are validated
# Skipping 237-th data point...
# 3.6456044707573945 and [False] are validated
# Skipping 238-th data point...
# -26.283990592462185 and [False] are validated
# Skipping 239-th data point...
# 2.7727005706090195 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 9.96223991289083 and [False] are validated
# Skipping 241-th data point...
# 10.323260458529386 and [False] are validated
# Skipping 242-th data point...
# 21.308494471951608 and [False] are validated
# Skipping 243-th data point...
# -15.496043562710582 and [False] are validated
# Skipping 244-th data point...
# -10.65213513346993 and [False] are validated
# Skipping 245-th data point...
# 37.910146919827106 and [False] are validated
# Skipping 246-th data point...
# Skipping 247-th data point...
# 4.00067574624656 and [False] are validated
# Skipping 248-th data point...
# -1.3402008345044212 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -16.433616526100447 and [False] are validated
# Skipping 250-th data point...
# 32.47058421783613 and [False] are validated
# Skipping 251-th data point...
# -10.554028238412114 and [False] are validated
# Skipping 252-th data point...
# -22.5457104741386 and [False] are validated
# Skipping 253-th data point...
# -9.014805546055033 and [False] are validated
# Skipping 254-th data point...
# -40.03412003451067 and [False] are validated
# Skipping 255-th data point...
# -13.025749299663635 and [False] are validated
# Skipping 256-th data point...
# -19.362571957046534 and [False] are validated
# Skipping 257-th data point...
# 12.348572618546488 and [False] are validated
# Skipping 258-th data point...
# -13.46828479119745 and [False] are validated
# Skipping 259-th data point...
# 17.75607871157697 and [False] are validated
# Skipping 260-th data point...
# 27.969679861386428 and [False] are validated
# Skipping 261-th data point...
# 15.623506725751984 and [False] are validated
# Skipping 262-th data point...
# -4.307765777201532 and [False] are validated
# Skipping 263-th data point...
# 2.822289934111859 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -30.49969880288119 and [False] are validated
# Skipping 265-th data point...
# -2.6755874504247936 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -17.208769361336664 and [False] are validated
# Skipping 267-th data point...
# 13.886527622985978 and [False] are validated
# Skipping 268-th data point...
# 51.45504778488948 and [False] are validated
# Skipping 269-th data point...
# 9.996432719476188 and [False] are validated
# Skipping 270-th data point...
# -39.82280297909333 and [False] are validated
# Skipping 271-th data point...
# -7.224603858287459 and [False] are validated
# Skipping 272-th data point...
# 2.449818507489093 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 1.747148505205274 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -14.616262512175062 and [False] are validated
# Skipping 275-th data point...
# 4.905834852738706 and [False] are validated
# Skipping 276-th data point...
# -24.850016738387744 and [False] are validated
# Skipping 277-th data point...
# -18.89817445370134 and [False] are validated
# Skipping 278-th data point...
# 12.915952832074229 and [False] are validated
# Skipping 279-th data point...
# -20.313264617596516 and [False] are validated
# Skipping 280-th data point...
# 10.764232109845144 and [False] are validated
# Skipping 281-th data point...
# -27.38927549312116 and [False] are validated
# Skipping 282-th data point...
# 35.29651767583472 and [False] are validated
# Skipping 283-th data point...
# -15.485398448081094 and [False] are validated
# Skipping 284-th data point...
# -4.473331436068882 and [False] are validated
# Skipping 285-th data point...
# 6.6122652218081175 and [False] are validated
# Skipping 286-th data point...
# -11.306999050021886 and [False] are validated
# Skipping 287-th data point...
# 2.8681192214260887 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 11.507134490402514 and [False] are validated
# Skipping 289-th data point...
# 19.212264650069706 and [False] are validated
# Skipping 290-th data point...
# 15.829948719459143 and [False] are validated
# Skipping 291-th data point...
# -3.4362092760534804 and [False] are validated
# Skipping 292-th data point...
# -2.9326354808720456 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 46.982171160500656 and [False] are validated
# Skipping 294-th data point...
# 18.99778136498584 and [False] are validated
# Skipping 295-th data point...
# -18.436473126404273 and [False] are validated
# Skipping 296-th data point...
# 1.999763275311036 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -6.70286277556385 and [False] are validated
# Skipping 298-th data point...
# -2.706684678462194 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -24.58990315416176 and [False] are validated
# Skipping 300-th data point...
# -8.238464687719063 and [False] are validated
# Skipping 301-th data point...
# 36.23111546387826 and [False] are validated
# Skipping 302-th data point...
# 11.58152601751006 and [False] are validated
# Skipping 303-th data point...
# -49.8232281630292 and [False] are validated
# Skipping 304-th data point...
# 24.334469849958936 and [False] are validated
# Skipping 305-th data point...
# 21.792590458183227 and [False] are validated
# Skipping 306-th data point...
# -7.185706086128331 and [False] are validated
# Skipping 307-th data point...
# 14.345270875664301 and [False] are validated
# Skipping 308-th data point...
# -17.187984216344013 and [False] are validated
# Skipping 309-th data point...
# -9.405114325327148 and [False] are validated
# Skipping 310-th data point...
# 29.970927213397076 and [False] are validated
# Skipping 311-th data point...
# -5.434600797394168 and [False] are validated
# Skipping 312-th data point...
# -37.39463323909982 and [False] are validated
# Skipping 313-th data point...
# -1.266064455626735 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -1.5717678582871362 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 23.967371387469193 and [False] are validated
# Skipping 316-th data point...
# 0.28672844351520044 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -8.431646228805855 and [False] are validated
# Skipping 318-th data point...
# 20.901122904624117 and [False] are validated
# Skipping 319-th data point...
# 2.4158046500222055 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -15.000453631314342 and [False] are validated
# Skipping 321-th data point...
# 23.09995121083235 and [False] are validated
# Skipping 322-th data point...
# 3.873235290335985 and [False] are validated
# Skipping 323-th data point...
# 0.05851933358875398 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# Skipping 325-th data point...
# -21.413367428331938 and [False] are validated
# Skipping 326-th data point...
# -10.553075523566747 and [False] are validated
# Skipping 327-th data point...
# 0.07165203665566566 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -3.893273900493599 and [False] are validated
# Skipping 329-th data point...
# 25.44856765633191 and [False] are validated
# Skipping 330-th data point...
# 4.348117054540069 and [False] are validated
# Skipping 331-th data point...
# 17.09807845272805 and [False] are validated
# Skipping 332-th data point...
# 0.18790709151698914 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 21.12576967492246 and [False] are validated
# Skipping 334-th data point...
# 7.950555131463078 and [False] are validated
# Skipping 335-th data point...
# 0.2684097077692022 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -0.26566177918039047 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -19.088772525819266 and [False] are validated
# Skipping 338-th data point...
# 10.138314402726214 and [False] are validated
# Skipping 339-th data point...
# -0.8040946907275792 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -10.039839203624092 and [False] are validated
# Skipping 341-th data point...
# 22.129235416241432 and [False] are validated
# Skipping 342-th data point...
# -25.004320517896023 and [False] are validated
# Skipping 343-th data point...
# -8.449917908648679 and [False] are validated
# Skipping 344-th data point...
# 20.55437497559067 and [False] are validated
# Skipping 345-th data point...
# 6.310458818405065 and [False] are validated
# Skipping 346-th data point...
# -0.9571785530551462 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 5.020070863002931 and [False] are validated
# Skipping 348-th data point...
# 3.588283420976826 and [False] are validated
# Skipping 349-th data point...
# -30.333250925718428 and [False] are validated
# Skipping 350-th data point...
# -6.9852377069592295 and [False] are validated
# Skipping 351-th data point...
# 32.33043309027498 and [False] are validated
# Skipping 352-th data point...
# -13.18648269554335 and [False] are validated
# Skipping 353-th data point...
# -6.366020282086681 and [False] are validated
# Skipping 354-th data point...
# -10.83241526618375 and [False] are validated
# Skipping 355-th data point...
# -1.740304466362748 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -11.662456626485962 and [False] are validated
# Skipping 357-th data point...
# 9.7348300431612 and [False] are validated
# Skipping 358-th data point...
# 3.946268245805331 and [False] are validated
# Skipping 359-th data point...
# 15.470952302140361 and [False] are validated
# Skipping 360-th data point...
# -21.01882332377921 and [False] are validated
# Skipping 361-th data point...
# -6.806809657658065 and [False] are validated
# Skipping 362-th data point...
# -4.5144526322427 and [False] are validated
# Skipping 363-th data point...
# 9.112938201771895 and [False] are validated
# Skipping 364-th data point...
# -15.86442394414069 and [False] are validated
# Skipping 365-th data point...
# 18.31307608516688 and [False] are validated
# Skipping 366-th data point...
# 23.728311810352174 and [False] are validated
# Skipping 367-th data point...
# -19.777446952711678 and [False] are validated
# Skipping 368-th data point...
# -9.817457897871314 and [False] are validated
# Skipping 369-th data point...
# -10.638630165841846 and [False] are validated
# Skipping 370-th data point...
# 52.64772409354997 and [False] are validated
# Skipping 371-th data point...
# -8.598002104157734 and [False] are validated
# Skipping 372-th data point...
# 33.55250884312269 and [False] are validated
# Skipping 373-th data point...
# -25.332639902132193 and [False] are validated
# Skipping 374-th data point...
# -19.793019323287268 and [False] are validated
# Skipping 375-th data point...
# -13.732090636964017 and [False] are validated
# Skipping 376-th data point...
# -16.913786228930448 and [False] are validated
# Skipping 377-th data point...
# -5.357974683169974 and [False] are validated
# Skipping 378-th data point...
# -14.175564054429962 and [False] are validated
# Skipping 379-th data point...
# -16.386831854691472 and [False] are validated
# Skipping 380-th data point...
# 23.169439929466552 and [False] are validated
# Skipping 381-th data point...
# 24.475872450263303 and [False] are validated
# Skipping 382-th data point...
# 18.985929967506316 and [False] are validated
# Skipping 383-th data point...
# 10.47997911168656 and [False] are validated
# Skipping 384-th data point...
# 1.8548613155910456 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -9.940613813318175 and [False] are validated
# Skipping 386-th data point...
# -19.06315009510184 and [False] are validated
# Skipping 387-th data point...
# 7.259914068653748 and [False] are validated
# Skipping 388-th data point...
# -23.472607850935958 and [False] are validated
# Skipping 389-th data point...
# -19.878418583507866 and [False] are validated
# Skipping 390-th data point...
# 23.058265124096195 and [False] are validated
# Skipping 391-th data point...
# 38.01298083444174 and [False] are validated
# Skipping 392-th data point...
# 7.865902763329615 and [False] are validated
# Skipping 393-th data point...
# 22.129143045892885 and [False] are validated
# Skipping 394-th data point...
# -4.916966348879667 and [False] are validated
# Skipping 395-th data point...
# -26.753483721753682 and [False] are validated
# Skipping 396-th data point...
# 12.24343237237168 and [False] are validated
# Skipping 397-th data point...
# 11.385786465401278 and [False] are validated
# Skipping 398-th data point...
# 1.4333710776048825 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -4.847509162102227 and [False] are validated
# Skipping 400-th data point...
# 19.24421157162196 and [False] are validated
# Skipping 401-th data point...
# -19.714660668549488 and [False] are validated
# Skipping 402-th data point...
# -15.475611577813154 and [False] are validated
# Skipping 403-th data point...
# -20.16213013520856 and [False] are validated
# Skipping 404-th data point...
# 1.6994592527165442 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -21.757860242185167 and [False] are validated
# Skipping 406-th data point...
# -13.68484361030487 and [False] are validated
# Skipping 407-th data point...
# -14.115111244543959 and [False] are validated
# Skipping 408-th data point...
# -5.212166646679163 and [False] are validated
# Skipping 409-th data point...
# -29.747488928079537 and [False] are validated
# Skipping 410-th data point...
# 1.74409984074534 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 24.946073013293557 and [False] are validated
# Skipping 412-th data point...
# 2.7098274463352383 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 30.826422896026415 and [False] are validated
# Skipping 414-th data point...
# 26.679963717538506 and [False] are validated
# Skipping 415-th data point...
# 15.55470094495709 and [False] are validated
# Skipping 416-th data point...
# 1.493716852737713 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 0.4500077649087914 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 15.275995447265199 and [False] are validated
# Skipping 419-th data point...
# -7.833412190080649 and [False] are validated
# Skipping 420-th data point...
# -37.650415029349276 and [False] are validated
# Skipping 421-th data point...
# 9.840081082059196 and [False] are validated
# Skipping 422-th data point...
# -22.621372598699423 and [False] are validated
# Skipping 423-th data point...
# -19.242824563807694 and [False] are validated
# Skipping 424-th data point...
# 0.0044789599157609335 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -1.9024975510693962 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -28.241512126312607 and [False] are validated
# Skipping 427-th data point...
# 3.309831282662806 and [False] are validated
# Skipping 428-th data point...
# 19.32279321722097 and [False] are validated
# Skipping 429-th data point...
# -22.566831405315657 and [False] are validated
# Skipping 430-th data point...
# 25.449666616975186 and [False] are validated
# Skipping 431-th data point...
# -31.20341650259888 and [False] are validated
# Skipping 432-th data point...
# 42.34648288741907 and [False] are validated
# Skipping 433-th data point...
# -8.225208609669666 and [False] are validated
# Skipping 434-th data point...
# 2.912339936537825 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -37.8406714497134 and [False] are validated
# Skipping 436-th data point...
# -1.2427213293861703 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 4.569643554363835 and [False] are validated
# Skipping 438-th data point...
# -1.723242081989891 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -11.261621541047473 and [False] are validated
# Skipping 440-th data point...
# -18.931290370556297 and [False] are validated
# Skipping 441-th data point...
# 22.61053239074622 and [False] are validated
# Skipping 442-th data point...
# 0.6161426999590027 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 30.81504753033545 and [False] are validated
# Skipping 444-th data point...
# -10.52964709589846 and [False] are validated
# Skipping 445-th data point...
# -8.695893867444338 and [False] are validated
# Skipping 446-th data point...
# 16.31188489192326 and [False] are validated
# Skipping 447-th data point...
# -32.45949924007128 and [False] are validated
# Skipping 448-th data point...
# -24.26926720305846 and [False] are validated
# Skipping 449-th data point...
# 21.949699427063273 and [False] are validated
# Skipping 450-th data point...
# -23.438678584463894 and [False] are validated
# Skipping 451-th data point...
# -36.38102030605096 and [False] are validated
# Skipping 452-th data point...
# 37.37054376146182 and [False] are validated
# Skipping 453-th data point...
# -27.87635295748411 and [False] are validated
# Skipping 454-th data point...
# 3.6823879665633923 and [False] are validated
# Skipping 455-th data point...
# 1.381703854485423 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -56.212566332361675 and [False] are validated
# Skipping 457-th data point...
# -5.346340463356178 and [False] are validated
# Skipping 458-th data point...
# 8.968264989582192 and [False] are validated
# Skipping 459-th data point...
# 7.086187630377212 and [False] are validated
# Skipping 460-th data point...
# 18.070413676070032 and [False] are validated
# Skipping 461-th data point...
# -7.7498262981086805 and [False] are validated
# Skipping 462-th data point...
# 14.250088841843214 and [False] are validated
# Skipping 463-th data point...
# -13.786581361601439 and [False] are validated
# Skipping 464-th data point...
# -28.2093483282555 and [False] are validated
# Skipping 465-th data point...
# -25.954567513624653 and [False] are validated
# Skipping 466-th data point...
# -29.242209103908294 and [False] are validated
# Skipping 467-th data point...
# 20.191719357823878 and [False] are validated
# Skipping 468-th data point...
# -30.29147018117113 and [False] are validated
# Skipping 469-th data point...
# 5.480776812986065 and [False] are validated
# Skipping 470-th data point...
# -5.31848388144866 and [False] are validated
# Skipping 471-th data point...
# -2.0529714690126317 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 27.272145903993994 and [False] are validated
# Skipping 473-th data point...
# -8.768547344305468 and [False] are validated
# Skipping 474-th data point...
# 12.232031230993666 and [False] are validated
# Skipping 475-th data point...
# 0.7512670276222342 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# Skipping 477-th data point...
# 45.99938248772947 and [False] are validated
# Skipping 478-th data point...
# -28.826834914307394 and [False] are validated
# Skipping 479-th data point...
# 25.782636708748896 and [False] are validated
# Skipping 480-th data point...
# 13.128131309799443 and [False] are validated
# Skipping 481-th data point...
# -9.59049989263568 and [False] are validated
# Skipping 482-th data point...
# 32.58637034883224 and [False] are validated
# Skipping 483-th data point...
# -36.96220224777073 and [False] are validated
# Skipping 484-th data point...
# -10.435333145981433 and [False] are validated
# Skipping 485-th data point...
# -24.169644085381524 and [False] are validated
# Skipping 486-th data point...
# 8.241669297429203 and [False] are validated
# Skipping 487-th data point...
# -22.26128202374355 and [False] are validated
# Skipping 488-th data point...
# 8.661278934826381 and [False] are validated
# Skipping 489-th data point...
# -3.7287283164310807 and [False] are validated
# Skipping 490-th data point...
# -9.587078853121687 and [False] are validated
# Skipping 491-th data point...
# 7.772944920666211 and [False] are validated
# Skipping 492-th data point...
# -5.372432478761282 and [False] are validated
# Skipping 493-th data point...
# -21.772696861180773 and [False] are validated
# Skipping 494-th data point...
# 56.027459792699574 and [False] are validated
# Skipping 495-th data point...
# -9.743343660582891 and [False] are validated
# Skipping 496-th data point...
# -44.35218160304029 and [False] are validated
# Skipping 497-th data point...
# -16.841973794427773 and [False] are validated
# Skipping 498-th data point...
# -25.345533767454604 and [False] are validated
# Skipping 499-th data point...
# 16.522912320810313 and [False] are validated
# Skipping 500-th data point...
# 6.43305319183172 and [False] are validated
# Skipping 501-th data point...
# 7.974256035806883 and [False] are validated
# Skipping 502-th data point...
# -7.400449316744886 and [False] are validated
# Skipping 503-th data point...
# -5.587004941138431 and [False] are validated
# Skipping 504-th data point...
# -7.418622072153365 and [False] are validated
# Skipping 505-th data point...
# -1.6238636827093944 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 16.706668707296707 and [False] are validated
# Skipping 507-th data point...
# 6.721508250106929 and [False] are validated
# Skipping 508-th data point...
# 10.002256592417334 and [False] are validated
# Skipping 509-th data point...
# 9.991178164984055 and [False] are validated
# Skipping 510-th data point...
# 17.688848747634758 and [False] are validated
# Skipping 511-th data point...
# 5.763000830805093 and [False] are validated
# Skipping 512-th data point...
# 7.176961453578375 and [False] are validated
# Skipping 513-th data point...
# 23.77612482386313 and [False] are validated
# Skipping 514-th data point...
# -13.30091836006224 and [False] are validated
# Skipping 515-th data point...
# -17.114851599030143 and [False] are validated
# Skipping 516-th data point...
# -23.71843198373712 and [False] are validated
# Skipping 517-th data point...
# 3.6582912724051186 and [False] are validated
# Skipping 518-th data point...
# -37.07464482438247 and [False] are validated
# Skipping 519-th data point...
# 9.243081921193546 and [False] are validated
# Skipping 520-th data point...
# -2.1838618900110536 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 22.692793996421138 and [False] are validated
# Skipping 522-th data point...
# -13.438346209299812 and [False] are validated
# Skipping 523-th data point...
# -4.066365708350135 and [False] are validated
# Skipping 524-th data point...
# 22.444066665867375 and [False] are validated
# Skipping 525-th data point...
# 27.662712935563047 and [False] are validated
# Skipping 526-th data point...
# -13.6030473150364 and [False] are validated
# Skipping 527-th data point...
# 3.6356246517432025 and [False] are validated
# Skipping 528-th data point...
# 5.888379553680963 and [False] are validated
# Skipping 529-th data point...
# 7.473068112422966 and [False] are validated
# Skipping 530-th data point...
# -5.251513186312443 and [False] are validated
# Skipping 531-th data point...
# 25.6276679624727 and [False] are validated
# Skipping 532-th data point...
# -37.79406967243091 and [False] are validated
# Skipping 533-th data point...
# -8.422604696021681 and [False] are validated
# Skipping 534-th data point...
# 8.958614655458938 and [False] are validated
# Skipping 535-th data point...
# 9.144496238986871 and [False] are validated
# Skipping 536-th data point...
# 27.05518061229526 and [False] are validated
# Skipping 537-th data point...
# 23.96450786402574 and [False] are validated
# Skipping 538-th data point...
# -5.710832506144476 and [False] are validated
# Skipping 539-th data point...
# 25.997424870612093 and [False] are validated
# Skipping 540-th data point...
# -14.280834875549097 and [False] are validated
# Skipping 541-th data point...
# 18.617747655836748 and [False] are validated
# Skipping 542-th data point...
# 36.21044956841986 and [False] are validated
# Skipping 543-th data point...
# 24.298882137099383 and [False] are validated
# Skipping 544-th data point...
# 2.1154076704824645 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -6.635575435442444 and [False] are validated
# Skipping 546-th data point...
# -30.571825925185724 and [False] are validated
# Skipping 547-th data point...
# 6.2107927582840805 and [False] are validated
# Skipping 548-th data point...
# -22.304344559418382 and [False] are validated
# Skipping 549-th data point...
# -15.862693272278737 and [False] are validated
# Skipping 550-th data point...
# -23.81491601473343 and [False] are validated
# Skipping 551-th data point...
# -9.207846653133103 and [False] are validated
# Skipping 552-th data point...
# -0.5593882897396458 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 5.472291623314103 and [False] are validated
# Skipping 554-th data point...
# -12.010132708279267 and [False] are validated
# Skipping 555-th data point...
# 21.385674127903663 and [False] are validated
# Skipping 556-th data point...
# -4.164105159799319 and [False] are validated
# Skipping 557-th data point...
# -15.754448665310383 and [False] are validated
# Skipping 558-th data point...
# 4.525845344868728 and [False] are validated
# Skipping 559-th data point...
# 39.27105667087632 and [False] are validated
# Skipping 560-th data point...
# 6.703211330702357 and [False] are validated
# Skipping 561-th data point...
# -7.257112547472142 and [False] are validated
# Skipping 562-th data point...
# -30.54922712237408 and [False] are validated
# Skipping 563-th data point...
# -4.3882464194414075 and [False] are validated
# Skipping 564-th data point...
# 4.698562501762312 and [False] are validated
# Skipping 565-th data point...
# -7.751617825111401 and [False] are validated
# Skipping 566-th data point...
# -33.30769276481999 and [False] are validated
# Skipping 567-th data point...
# -17.011307790068678 and [False] are validated
# Skipping 568-th data point...
# 29.090769217755152 and [False] are validated
# Skipping 569-th data point...
# 28.680020074609217 and [False] are validated
# Skipping 570-th data point...
# -17.73278338409196 and [False] are validated
# Skipping 571-th data point...
# 13.455135743988437 and [False] are validated
# Skipping 572-th data point...
# -23.571455695403472 and [False] are validated
# Skipping 573-th data point...
# 28.086325639899048 and [False] are validated
# Skipping 574-th data point...
# 4.904716957884727 and [False] are validated
# Skipping 575-th data point...
# 18.992829972330675 and [False] are validated
# Skipping 576-th data point...
# -34.30186694365078 and [False] are validated
# Skipping 577-th data point...
# 13.552742038497762 and [False] are validated
# Skipping 578-th data point...
# -0.15348127369006945 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 17.03858141581685 and [False] are validated
# Skipping 580-th data point...
# 18.297355961956995 and [False] are validated
# Skipping 581-th data point...
# 1.315693789494989 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -12.016592781918295 and [False] are validated
# Skipping 583-th data point...
# 15.593923643589886 and [False] are validated
# Skipping 584-th data point...
# -1.2030899881025536 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -17.45569907055285 and [False] are validated
# Skipping 586-th data point...
# -18.403044629153715 and [False] are validated
# Skipping 587-th data point...
# -29.543288326247634 and [False] are validated
# Skipping 588-th data point...
# -10.205823191261265 and [False] are validated
# Skipping 589-th data point...
# 22.053840921487566 and [False] are validated
# Skipping 590-th data point...
# 3.556595994108685 and [False] are validated
# Skipping 591-th data point...
# -10.595354118460813 and [False] are validated
# Skipping 592-th data point...
# 16.097118763601593 and [False] are validated
# Skipping 593-th data point...
# -16.649532434467776 and [False] are validated
# Skipping 594-th data point...
# 1.907005486655571 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -3.5926074545103064 and [False] are validated
# Skipping 596-th data point...
# 15.582612511767044 and [False] are validated
# Skipping 597-th data point...
# -31.544567418390017 and [False] are validated
# Skipping 598-th data point...
# -17.003954916293115 and [False] are validated
# Skipping 599-th data point...
# -32.76491318189067 and [False] are validated
# Skipping 600-th data point...
# -5.1919344361854005 and [False] are validated
# Skipping 601-th data point...
# 24.22855007264861 and [False] are validated
# Skipping 602-th data point...
# -10.108944193070544 and [False] are validated
# Skipping 603-th data point...
# -10.213678763913014 and [False] are validated
# Skipping 604-th data point...
# 17.434488483682728 and [False] are validated
# Skipping 605-th data point...
# 21.370991169105995 and [False] are validated
# Skipping 606-th data point...
# -1.7714213453757985 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 13.694297080997844 and [False] are validated
# Skipping 608-th data point...
# -21.53909081755893 and [False] are validated
# Skipping 609-th data point...
# 27.559486678508275 and [False] are validated
# Skipping 610-th data point...
# 42.97412587874103 and [False] are validated
# Skipping 611-th data point...
# 10.424315823774498 and [False] are validated
# Skipping 612-th data point...
# -41.68663242685601 and [False] are validated
# Skipping 613-th data point...
# -11.164605247955686 and [False] are validated
# Skipping 614-th data point...
# 12.256506433386427 and [False] are validated
# Skipping 615-th data point...
# -8.429659943327255 and [False] are validated
# Skipping 616-th data point...
# 25.44397108500195 and [False] are validated
# Skipping 617-th data point...
# 11.763145288717304 and [False] are validated
# Skipping 618-th data point...
# -14.129510015315931 and [False] are validated
# Skipping 619-th data point...
# 0.6452962154250559 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# ...
# -26.774474122711467 and [False] are validated
# Skipping 792-th data point...
# -17.71336368012832 and [False] are validated
# Skipping 793-th data point...
# -17.01565497256307 and [False] are validated
# Skipping 794-th data point...
# -14.575803927547668 and [False] are validated
# Skipping 795-th data point...
# -9.634341018710519 and [False] are validated
# Skipping 796-th data point...
# 4.852056261098829 and [False] are validated
# Skipping 797-th data point...
# 17.313493023347394 and [False] are validated
# Skipping 798-th data point...
# 21.62633915537073 and [False] are validated
# Skipping 799-th data point...
# -16.756461223355636 and [False] are validated
# Skipping 800-th data point...
# -16.894059974059655 and [False] are validated
# Skipping 801-th data point...
# 26.31643680032446 and [False] are validated
# Skipping 802-th data point...
# 12.93487870837289 and [False] are validated
# Skipping 803-th data point...
# 1.6572968373799226 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 9.466733511099342 and [False] are validated
# Skipping 805-th data point...
# -0.5960756370288127 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 10.491693660952293 and [False] are validated
# Skipping 807-th data point...
# -6.72133393011481 and [False] are validated
# Skipping 808-th data point...
# 5.376098688784616 and [False] are validated
# Skipping 809-th data point...
# -30.210921007389928 and [False] are validated
# Skipping 810-th data point...
# -13.75568589650862 and [False] are validated
# Skipping 811-th data point...
# -13.54022353580687 and [False] are validated
# Skipping 812-th data point...
# -7.487800664138282 and [False] are validated
# Skipping 813-th data point...
# -18.530265095594963 and [False] are validated
# Skipping 814-th data point...
# -10.670872516461635 and [False] are validated
# Skipping 815-th data point...
# -30.288281247962413 and [False] are validated
# Skipping 816-th data point...
# 10.974009527898005 and [False] are validated
# Skipping 817-th data point...
# -1.6502703782278896 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -34.10415215552034 and [False] are validated
# Skipping 819-th data point...
# -16.696598210933463 and [False] are validated
# Skipping 820-th data point...
# 6.732028551243338 and [False] are validated
# Skipping 821-th data point...
# -10.860438927715794 and [False] are validated
# Skipping 822-th data point...
# -13.938829202761934 and [False] are validated
# Skipping 823-th data point...
# -1.491853540161527 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 6.871950703564323 and [False] are validated
# Skipping 825-th data point...
# -28.727049140783212 and [False] are validated
# Skipping 826-th data point...
# 11.002569624357587 and [False] are validated
# Skipping 827-th data point...
# -16.005865632147533 and [False] are validated
# Skipping 828-th data point...
# -0.35855936499597457 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -0.7084028138301905 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -10.541322364795482 and [False] are validated
# Skipping 831-th data point...
# -20.47319492261429 and [False] are validated
# Skipping 832-th data point...
# -5.713730961845272 and [False] are validated
# Skipping 833-th data point...
# 32.5066061815039 and [False] are validated
# Skipping 834-th data point...
# -27.233500609272618 and [False] are validated
# Skipping 835-th data point...
# 33.84626038209751 and [False] are validated
# Skipping 836-th data point...
# -5.194423421530648 and [False] are validated
# Skipping 837-th data point...
# 0.7074283417727824 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -21.734216227694546 and [False] are validated
# Skipping 839-th data point...
# -15.425388333549616 and [False] are validated
# Skipping 840-th data point...
# -10.058193000760383 and [False] are validated
# Skipping 841-th data point...
# -20.913899417558245 and [False] are validated
# Skipping 842-th data point...
# -4.178359147417435 and [False] are validated
# Skipping 843-th data point...
# -8.140317836135422 and [False] are validated
# Skipping 844-th data point...
# 37.01562284871467 and [False] are validated
# Skipping 845-th data point...
# -23.319483713609223 and [False] are validated
# Skipping 846-th data point...
# 2.053810334971745 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 4.956925638036495 and [False] are validated
# Skipping 848-th data point...
# -21.40641097303675 and [False] are validated
# Skipping 849-th data point...
# 13.73654990905677 and [False] are validated
# Skipping 850-th data point...
# -7.966540257632562 and [False] are validated
# Skipping 851-th data point...
# -49.84779303166135 and [False] are validated
# Skipping 852-th data point...
# 13.196992242091302 and [False] are validated
# Skipping 853-th data point...
# -22.338817682047278 and [False] are validated
# Skipping 854-th data point...
# -20.95549892278198 and [False] are validated
# Skipping 855-th data point...
# 13.758041657847963 and [False] are validated
# Skipping 856-th data point...
# -6.943229648368996 and [False] are validated
# Skipping 857-th data point...
# 18.355443011030005 and [False] are validated
# Skipping 858-th data point...
# 24.203321907306375 and [False] are validated
# Skipping 859-th data point...
# -12.898569206445957 and [False] are validated
# Skipping 860-th data point...
# 15.865249919100613 and [False] are validated
# Skipping 861-th data point...
# -15.109216027857638 and [False] are validated
# Skipping 862-th data point...
# 44.66231834264353 and [False] are validated
# Skipping 863-th data point...
# -13.859140090624303 and [False] are validated
# Skipping 864-th data point...
# 20.52174881920008 and [False] are validated
# Skipping 865-th data point...
# 16.87580051763151 and [False] are validated
# Skipping 866-th data point...
# 6.3217564421786765 and [False] are validated
# Skipping 867-th data point...
# -13.410863228333662 and [False] are validated
# Skipping 868-th data point...
# Skipping 869-th data point...
# -43.07176225889104 and [False] are validated
# Skipping 870-th data point...
# 4.488400767645007 and [False] are validated
# Skipping 871-th data point...
# 6.992306620567705 and [False] are validated
# Skipping 872-th data point...
# 2.669988381227429 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -59.46612342585115 and [False] are validated
# Skipping 874-th data point...
# -25.31272890179622 and [False] are validated
# Skipping 875-th data point...
# -14.961819656973251 and [False] are validated
# Skipping 876-th data point...
# 5.833178663780922 and [False] are validated
# Skipping 877-th data point...
# 5.78677811285969 and [False] are validated
# Skipping 878-th data point...
# -3.4044758394235846 and [False] are validated
# Skipping 879-th data point...
# 12.704910732079133 and [False] are validated
# Skipping 880-th data point...
# -20.524847506058 and [False] are validated
# Skipping 881-th data point...
# 12.204700113879925 and [False] are validated
# Skipping 882-th data point...
# 9.494842096797822 and [False] are validated
# Skipping 883-th data point...
# 7.5510946567582105 and [False] are validated
# Skipping 884-th data point...
# -3.6408086217131164 and [False] are validated
# Skipping 885-th data point...
# 36.614876496625236 and [False] are validated
# Skipping 886-th data point...
# 9.863913769797572 and [False] are validated
# Skipping 887-th data point...
# -19.366717265071177 and [False] are validated
# Skipping 888-th data point...
# 4.966109514719684 and [False] are validated
# Skipping 889-th data point...
# 15.049667541484371 and [False] are validated
# Skipping 890-th data point...
# -11.76217197848619 and [False] are validated
# Skipping 891-th data point...
# 21.78544493862198 and [False] are validated
# Skipping 892-th data point...
# 7.640674114320214 and [False] are validated
# Skipping 893-th data point...
# -46.849566753306945 and [False] are validated
# Skipping 894-th data point...
# 5.993439546758527 and [False] are validated
# Skipping 895-th data point...
# -8.120583088254307 and [False] are validated
# Skipping 896-th data point...
# 10.74359629083472 and [False] are validated
# Skipping 897-th data point...
# 18.884296805036286 and [False] are validated
# Skipping 898-th data point...
# 3.9032409428363604 and [False] are validated
# Skipping 899-th data point...
# 33.305044678893914 and [False] are validated
# Skipping 900-th data point...
# -3.5741376912699145 and [False] are validated
# Skipping 901-th data point...
# 12.496356461077504 and [False] are validated
# Skipping 902-th data point...
# 16.098851472746947 and [False] are validated
# Skipping 903-th data point...
# -1.946919377854655 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 15.575486159555645 and [False] are validated
# Skipping 905-th data point...
# -11.893459743243376 and [False] are validated
# Skipping 906-th data point...
# -8.45136838042437 and [False] are validated
# Skipping 907-th data point...
# -26.24977380672625 and [False] are validated
# Skipping 908-th data point...
# 4.828182327400939 and [False] are validated
# Skipping 909-th data point...
# 6.505033517086881 and [False] are validated
# Skipping 910-th data point...
# 23.585263171584586 and [False] are validated
# Skipping 911-th data point...
# 15.822800087117672 and [False] are validated
# Skipping 912-th data point...
# -5.695911132948663 and [False] are validated
# Skipping 913-th data point...
# -23.563593746685537 and [False] are validated
# Skipping 914-th data point...
# 8.65700805039948 and [False] are validated
# Skipping 915-th data point...
# 22.215063448292838 and [False] are validated
# Skipping 916-th data point...
# 15.103699476078866 and [False] are validated
# Skipping 917-th data point...
# 21.689550497145753 and [False] are validated
# Skipping 918-th data point...
# -4.237790623964851 and [False] are validated
# Skipping 919-th data point...
# -9.33237936351291 and [False] are validated
# Skipping 920-th data point...
# -14.73802704463598 and [False] are validated
# Skipping 921-th data point...
# -1.1179293322719102 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -1.571815919376388 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 4.133552570782324 and [False] are validated
# Skipping 924-th data point...
# -2.58594914071016 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# Skipping 926-th data point...
# -15.533881059442878 and [False] are validated
# Skipping 927-th data point...
# 18.832380271029816 and [False] are validated
# Skipping 928-th data point...
# 1.5303612448742259 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -3.488878685705643 and [False] are validated
# Skipping 930-th data point...
# -14.948585064984094 and [False] are validated
# Skipping 931-th data point...
# -26.638262207821718 and [False] are validated
# Skipping 932-th data point...
# 26.159283850986874 and [False] are validated
# Skipping 933-th data point...
# 11.092774162636143 and [False] are validated
# Skipping 934-th data point...
# -32.47835685139934 and [False] are validated
# Skipping 935-th data point...
# 15.262846014193139 and [False] are validated
# Skipping 936-th data point...
# 18.449623404662184 and [False] are validated
# Skipping 937-th data point...
# 2.4875224460185903 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 31.96221791503518 and [False] are validated
# Skipping 939-th data point...
# 4.334392842457659 and [False] are validated
# Skipping 940-th data point...
# -28.336470558983798 and [False] are validated
# Skipping 941-th data point...
# 7.30338002096642 and [False] are validated
# Skipping 942-th data point...
# 4.897946034254585 and [False] are validated
# Skipping 943-th data point...
# -12.065936975563098 and [False] are validated
# Skipping 944-th data point...
# 11.4711767375485 and [False] are validated
# Skipping 945-th data point...
# -33.35330532381724 and [False] are validated
# Skipping 946-th data point...
# 19.811336548855788 and [False] are validated
# Skipping 947-th data point...
# -17.562434072109053 and [False] are validated
# Skipping 948-th data point...
# -19.698922502340647 and [False] are validated
# Skipping 949-th data point...
# -2.2764954461495375 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 8.659458560872707 and [False] are validated
# Skipping 951-th data point...
# 3.2784812718685923 and [False] are validated
# Skipping 952-th data point...
# -14.853183315447565 and [False] are validated
# Skipping 953-th data point...
# -10.12178582383777 and [False] are validated
# Skipping 954-th data point...
# -22.66084694754924 and [False] are validated
# Skipping 955-th data point...
# -4.4935980325974025 and [False] are validated
# Skipping 956-th data point...
# 21.500424290218195 and [False] are validated
# Skipping 957-th data point...
# -0.08525875287752327 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 17.188285095189062 and [False] are validated
# Skipping 959-th data point...
# 29.108026754523834 and [False] are validated
# Skipping 960-th data point...
# -11.76037038073934 and [False] are validated
# Skipping 961-th data point...
# -3.7314650611072935 and [False] are validated
# Skipping 962-th data point...
# 43.423857221249904 and [False] are validated
# Skipping 963-th data point...
# 28.886868239598904 and [False] are validated
# Skipping 964-th data point...
# -33.44809051624705 and [False] are validated
# Skipping 965-th data point...
# 7.742966321218131 and [False] are validated
# Skipping 966-th data point...
# 0.011199846793907994 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# 16.529062217175248 and [False] are validated
# Skipping 968-th data point...
# -14.899575349701106 and [False] are validated
# Skipping 969-th data point...
# -16.792167440813444 and [False] are validated
# Skipping 970-th data point...
# -13.52141430587219 and [False] are validated
# Skipping 971-th data point...
# -11.438570923968657 and [False] are validated
# Skipping 972-th data point...
# 16.306483336180285 and [False] are validated
# Skipping 973-th data point...
# -23.6240234629776 and [False] are validated
# Skipping 974-th data point...
# -12.452277999186379 and [False] are validated
# Skipping 975-th data point...
# -35.780247810028825 and [False] are validated
# Skipping 976-th data point...
# 20.14235646824746 and [False] are validated
# Skipping 977-th data point...
# 25.42060198862281 and [False] are validated
# Skipping 978-th data point...
# -6.541468617275729 and [False] are validated
# Skipping 979-th data point...
# -5.95898729626446 and [False] are validated
# Skipping 980-th data point...
# 9.064438045657946 and [False] are validated
# Skipping 981-th data point...
# 29.48964014756511 and [False] are validated
# Skipping 982-th data point...
# 8.172214951278345 and [False] are validated
# Skipping 983-th data point...
# -13.950838849502292 and [False] are validated
# Skipping 984-th data point...
# -32.37645143972881 and [False] are validated
# Skipping 985-th data point...
# -22.302525253269753 and [False] are validated
# Skipping 986-th data point...
# 1.4643890062493008 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!
# -13.106550464015887 and [False] are validated
# Skipping 988-th data point...
# 3.899354119815172 and [False] are validated
# Skipping 989-th data point...
# -11.05848032472468 and [False] are validated
# Skipping 990-th data point...
# -21.16292862588823 and [False] are validated
# Skipping 991-th data point...
# -23.54063262906142 and [False] are validated
# Skipping 992-th data point...
# 31.247090187464593 and [False] are validated
# Skipping 993-th data point...
# 17.779754983672863 and [False] are validated
# Skipping 994-th data point...
# 34.610359036559174 and [False] are validated
# Skipping 995-th data point...
# 10.799018015102057 and [False] are validated
# Skipping 996-th data point...
# -8.59982817229678 and [False] are validated
# Skipping 997-th data point...
# 26.466818449798758 and [False] are validated
# Skipping 998-th data point...
# -0.6613600272353573 and [ True] are equal
# Accelerometer info from a_01 has been added successfully!

# %%
print(f'score: {val_passed_counter/ n_incoming}')
# Out:
# score: 0.986

# %%
# making target data (we will use only for validation, not training)
y_proper = np.full((number_of_proper_data,), 0)
y_anomalous = np.full((number_of_anomal_data,), 1)
Y = np.concatenate((y_proper, y_anomalous))

# %%
from river import anomaly
from river import compose
from river import datasets
from river import metrics
from river import preprocessing

model = anomaly.QuantileFilter(
     anomaly.OneClassSVM(nu=0.2),
     q=0.995)
auc = metrics.ROCAUC()

# %%
data = stream.iter_array(X=X_train, y=Y, shuffle=True)
evaluate.progressive_val_score(
     dataset=data,
     model=model,
     metric=auc,
     print_every=1000
 )
# Out:
# [1,000] ROCAUC: 58.89%
# [2,000] ROCAUC: 57.97%
# [3,000] ROCAUC: 59.69%
# [4,000] ROCAUC: 60.08%
# [5,000] ROCAUC: 58.54%
# [6,000] ROCAUC: 59.97%
# [7,000] ROCAUC: 60.08%
# [8,000] ROCAUC: 59.79%
# [9,000] ROCAUC: 60.59%
# [10,000] ROCAUC: 60.92%
# [10,100] ROCAUC: 61.20%
# ROCAUC: 61.20%

# %%
svm_acc = metrics.Accuracy()
for i in range(n_incoming):

    incoming_data = ["a_01", "accel", rng.normal(loc=0.0, scale=20.0)]
    X_data_point = np.array(incoming_data[2]).reshape(-1, 1)
    x = { 0 : incoming_data[2]}
    score = model.score_one(x)
    is_anomaly = model.classify(score)
    ground_truth = validate_result(incoming_data, mu, sigma)
    model = model.learn_one(x)
    auc = auc.update(ground_truth, is_anomaly)
    

auc
# Out:
# ROCAUC: 53.53%

# %%
KNN = neighbors.KNNRegressor(n_neighbors=3, window_size=100)
metric = metrics.R2()

evaluate.progressive_val_score(dataset=data,
                               model=KNN,
                               metric=metric,
                               print_every=1000)
# Out:
# R2: 0.

# %%
accuracy = metrics.Accuracy()
for i in range(n_incoming):

    incoming_data = ["a_01", "accel", rng.normal(loc=0.0, scale=20.0)]
    x = { 0 : incoming_data[2]}
    is_anomaly = KNN.predict_one(x)
    ground_truth = validate_result(incoming_data, mu, sigma)
    KNN = KNN.learn_one(x, ground_truth)
    accuracy = accuracy.update(ground_truth, is_anomaly)
    metric = metric.update(ground_truth, is_anomaly)

# %%
metric
# Out:
# R2: 0.841996

# %%
accuracy
# Out:
# Accuracy: 94.60%

# %%
data = stream.iter_array(X=X_train, y=Y, shuffle=True)

# %%
from river.datasets import synth
from river import evaluate
from river import metrics
from river import tree

gen = synth.Agrawal(classification_function=0, seed=42)
# Take 1000 instances from the infinite data generator

tree = tree.HoeffdingTreeClassifier(
    grace_period=100,
    delta=1e-5,
)


evaluate.progressive_val_score(data, tree, metrics.Accuracy(), print_every=1000)
# Out:
# [1,000] Accuracy: 99.30%
# [2,000] Accuracy: 99.50%
# [3,000] Accuracy: 99.47%
# [4,000] Accuracy: 99.57%
# [5,000] Accuracy: 99.66%
# [6,000] Accuracy: 99.68%
# [7,000] Accuracy: 99.69%
# [8,000] Accuracy: 99.72%
# [9,000] Accuracy: 99.76%
# [10,000] Accuracy: 99.77%
# [10,100] Accuracy: 99.77%
# Accuracy: 99.77%

# %%
k_means = cluster.KMeans(n_clusters=2, halflife=0.1, sigma=3, seed=42)

# %%
init_prediction = np.zeros((number_of_proper_data+number_of_anomal_data,), dtype=int)
for i, (x, _) in enumerate(stream.iter_array(X_train)):
    k_means = k_means.learn_one(x)
    init_prediction [i] = k_means.predict_one(x)

# %%
k_means_acc = metrics.Accuracy()

for i in range(n_incoming):

    incoming_data = ["a_01", "accel", rng.normal(loc=0.0, scale=20.0)]
    x = { 0 : incoming_data[2]}
    is_anomaly = k_means.learn_predict_one(x)
    ground_truth = validate_result(incoming_data, mu, sigma)
    k_means_acc = k_means_acc.update(ground_truth, is_anomaly)

# %%
k_means_acc
# Out:
# Accuracy: 49.20%

# %%
dbstream = cluster.DBSTREAM(clustering_threshold = 3,
                             fading_factor = 0.05,
                             intersection_factor = 0.5)

# %%
for i, (x, _) in enumerate(stream.iter_array(X_train)):
    print(x)
    dbstream = dbstream.learn_one(x)

# %%
from sklearn.cluster import DBSCAN
clustering = DBSCAN(eps=3, min_samples=2).fit(X)

# %%
dbstream_acc = metrics.Accuracy()

n = range(n_incoming)
ground_truth = np.zeros((n_incoming,), dtype=int)
prediction = np.zeros((n_incoming,), dtype=int)
offline_prediction = np.zeros((n_incoming,), dtype=int)
score = 0
total_true = 0
for i in n:

    incoming_data = ["a_01", "accel", rng.normal(loc=0.0, scale=20.0)]
    x = { 0 : incoming_data[2]}
    dbstream = dbstream.learn_one(x)
    #offline_prediction[i] = clustering.fit_predict(np.array(incoming_data[2]).reshape(-1, 1))
    #print(offline_prediction[i])
    ground_truth[i] = validate_result(incoming_data, mu, sigma)
    prediction[i] = dbstream.predict_one(x)
    if ground_truth[i]==0:
        total_true += 1
        if prediction[i]==0:
            score += 1
    
score = score/total_true
score
# Out:
# 0.0

# %%
plt.hist(prediction);

# %%
plt.hist(ground_truth);

# %%
plt.hist(init_prediction);

# %%
random_state = 0
rng = np.random.RandomState(random_state)
# Generate some example data
X, labels, centers = make_blobs(n_samples=5000, centers=1, random_state=random_state, n_features = 3, return_centers=True)
bias = 5
anomalous_data, ano_lbl = make_blobs(n_samples=500, centers=[[centers[0][0], centers[0][1]-bias, centers[0][2]]], random_state=random_state, n_features = 3)
X_inj=np.concatenate((X, anomalous_data), axis=0)
labels_inj=np.concatenate((labels, np.ones(500,)), axis=0)
labels_inj = labels_inj.reshape(5500,1)
data = np.concatenate((X_inj, labels_inj), axis=1)
data = rng.permutation(data)
X_inj_rand = data[:, :3]
labels_inj_rand = data[:, 3]

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('DBStream Clustering Example Ground truth')
ax.scatter(X_inj_rand[:, 0], X_inj_rand[:, 1], X_inj_rand[:, 2], c=labels_inj_rand)
plt.show()

# %%
# Perform DBSCAN clustering
dbscan = DBSCAN(eps=0.515, min_samples=5)
y_pred = dbscan.fit_predict(X_inj)
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('DBSCAN Clustering Example')
ax.scatter(X_inj[:, 0], X_inj[:, 1], X_inj[:, 2], c=y_pred)
print(f'Accuracy {accuracy_score(y_pred, labels_inj)*100} %')
plt.show()
# Out:
# Accuracy 88.83636363636363 %

# %%
dbstream_exp = cluster.DBSTREAM(clustering_threshold = 5.75)

for i, (x, _) in enumerate(stream.iter_array(X_inj)):
    dbstream_exp = dbstream_exp.learn_one(x)
    y_pred[i] = dbstream_exp.predict_one(x)

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('DBStream Clustering Example')
ax.scatter(X_inj[:, 0], X_inj[:, 1], X_inj[:, 2], c=y_pred)
print(f'Accuracy {accuracy_score(y_pred, labels_inj)*100} %')
plt.show()
# Out:
# Accuracy 91.98181818181818 %

# %%
# Perform DBSCAN clustering
dbscan = DBSCAN(eps=0.515, min_samples=5)
y_pred = dbscan.fit_predict(X_inj_rand)
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('DBSCAN Clustering Example')
ax.scatter(X_inj_rand[:, 0], X_inj_rand[:, 1], X_inj_rand[:, 2], c=y_pred)
print(f'Accuracy {accuracy_score(y_pred, labels_inj_rand)*100} %')
plt.show()
# Out:
# Accuracy 95.92727272727272 %

# %%
dbstream_exp = cluster.DBSTREAM(clustering_threshold = 5.75)

for i, (x, _) in enumerate(stream.iter_array(X_inj_rand)):
    dbstream_exp = dbstream_exp.learn_one(x)
    y_pred[i] = dbstream_exp.predict_one(x)
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('DBStream Clustering after data preprocessing')
ax.scatter(X_inj_rand[:, 0], X_inj_rand[:, 1], X_inj_rand[:, 2], c=y_pred)
print(f'Accuracy {accuracy_score(y_pred, labels_inj_rand)*100} %')
plt.show()
# Out:
# Accuracy 98.05454545454545 %

# %%
import tensorflow as tf
from tensorflow.keras.layers import LayerNormalization, MultiHeadAttention, Dense, Dropout, Flatten

class TimeSeriesTransformer(tf.keras.Model):
    def __init__(self, input_dim, d_model, nhead, num_layers, dropout):
        super(TimeSeriesTransformer, self).__init__()
        self.multi_head_attention = MultiHeadAttention(
            key_dim=d_model, num_heads=nhead, dropout=dropout
        )
        self.fc = Dense(units=input_dim, activation="relu")
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        self.dropout = Dropout(dropout)
        self.flatten = Flatten()  # Add Flatten layer

    def call(self, x):
        attn_output = self.multi_head_attention(x, x)
        attn_output = self.dropout(attn_output)
        x = self.layernorm1(x + attn_output)
        fc_output = self.fc(x)  # Removed 'self.flatten' here
        fc_output = self.dropout(fc_output)
        output = self.layernorm2(attn_output + fc_output)  # Removed 'self.flatten' here
        return output
